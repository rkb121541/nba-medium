# %% [markdown]
# # Miami Heat data

# %%
# %pip install pandas
# %pip install requests
# %pip install beautifulsoup4
# %pip install --upgrade pip
# %pip install lxml
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.13/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: requests in ./.venv/lib/python3.13/site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.13/site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.13/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.13/site-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.13/site-packages (from requests) (2025.4.26)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: beautifulsoup4 in ./.venv/lib/python3.13/site-packages (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.13/site-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in ./.venv/lib/python3.13/site-packages (from beautifulsoup4) (4.13.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pip in ./.venv/lib/python3.13/site-packages (25.1.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: lxml in ./.venv/lib/python3.13/site-packages (5.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
import random

# %%
url = 'https://www.basketball-reference.com/teams/MIA/2025.html'

r = requests.get(url)
time.sleep(random.uniform(2,5))
print(r)
if r.status_code == 429:
    wait_time = r.headers.get("Retry-After")
    print(f"Wait {wait_time} seconds")
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(r.content, 'lxml') # object that represents the html file

per_game = soup.find(name = 'table', attrs={'id': 'per_game_stats'})

# %%
stats = []

for row in per_game.find_all('tr')[1:-1]:
    player = {}
    player['Name'] = row.find('td', {'data-stat': 'name_display'}).text
    player['Age'] = row.find('td', {'data-stat' : 'age'}).text
    player['Min PG'] = row.find('td', {'data-stat' : 'mp_per_g'}).text
    player['Field Goal %'] = row.find('td', {'data-stat' : 'fg_pct'}).text
    player['Rebounds PG'] = row.find('td', {'data-stat' : 'trb_per_g'}).text
    player['Assists PG'] = row.find('td', {'data-stat' : 'ast_per_g'}).text
    player['Steals PG'] = row.find('td', {'data-stat' : 'stl_per_g'}).text
    player['Blocks PG'] = row.find('td', {'data-stat' : 'blk_per_g'}).text
    player['Turnovers PG'] = row.find('td', {'data-stat' : 'tov_per_g'}).text
    player['Points PG'] = row.find('td', {'data-stat' : 'pts_per_g'}).text
    stats.append(player)

df1 = pd.DataFrame(stats)
df1
# Out:
#                  Name Age Min PG Field Goal % Rebounds PG Assists PG  \
# 0         Tyler Herro  25   35.4         .472         5.2        5.5
# 1         Bam Adebayo  27   34.3         .485         9.6        4.3
# 2      Andrew Wiggins  29   32.1         .458         4.2        3.3
# 3     Davion Mitchell  26   31.6         .504         2.7        5.3
# 4        Jimmy Butler  35   30.6         .540         5.2        4.8
# 5        Terry Rozier  30   25.9         .391         3.7        2.6
# 6        Nikola Jović  21   25.1         .456         3.9        2.8
# 7   Haywood Highsmith  28   24.6         .458         3.4        1.5
# 8     Duncan Robinson  30   24.1         .437         2.3        2.4
# 9         Kel'el Ware  20   22.2         .554         7.4        0.9
# 10   Jaime Jaquez Jr.  23   20.7         .461         4.4        2.5
# 11          Dru Smith  27   19.1         .508         2.6        1.6
# 12    Josh Richardson  31   18.8         .289         1.5        1.5
# 13      Kyle Anderson  31   18.4         .493         3.8        2.6
# 14         Alec Burks  33   17.6         .424         2.5        1.1
# 15      Pelle Larsson  23   14.2         .438         1.7        1.2
# 16      Thomas Bryant  27   11.5         .429         3.2        0.4
# 17         Kevin Love  36   10.9         .357         4.1        1.0
# 18     Keshad Johnson  23    6.1         .692         1.8        0.3
# 19   Josh Christopher  23    4.9         .355         0.6        0.6
# 20     Isaiah Stevens  24    2.0         .000         0.7        0.0
#
#    Steals PG Blocks PG Turnovers PG Points PG
# 0        0.9       0.2          2.6      23.9
# 1        1.3       0.7          2.1      18.1
# 2        1.2       1.0          2.5      19.0
# 3        1.4       0.3          1.7      10.3
# 4        1.1       0.4          1.2      17.0
# 5        0.6       0.2          1.2      10.6
# 6        0.8       0.3          1.3      10.7
# 7        0.9       0.5          0.7       6.5
# 8        0.5       0.1          1.2      11.0
# 9        0.6       1.1          0.9       9.3
# 10       0.9       0.2          1.5       8.6
# 11       1.5       0.4          1.2       6.2
# 12       1.0       0.1          1.0       4.0
# 13       0.6       0.5          0.7       6.7
# 14       0.6       0.1          0.6       7.3
# 15       0.6       0.1          0.4       4.6
# 16       0.1       0.9          0.2       4.1
# 17       0.7       0.2          0.6       5.3
# 18       0.3       0.3          0.3       2.7
# 19       0.4       0.2          0.4       2.0
# 20       0.3       0.0          0.0       0.0

# %%
insta_handle = []

for row in per_game.find_all('tr')[1:-1]:
    player = {}
    name_td = row.find('td', {'data-stat': 'name_display'})
    a_tag = name_td.find('a')['href']
    player_url = 'https://www.basketball-reference.com' + a_tag
    player_request = requests.get(player_url)
    time.sleep(random.uniform(2,5))
    player_soup = BeautifulSoup(player_request.content, 'lxml')
    player_info = player_soup.find(name = 'div', attrs = {'id' : 'info', 'class' : 'players'})
    player['Name'] = row.find('a').text.strip()
    player_links = []
    for link in player_info.find_all('a'):
        player_links.append(link.get('href'))
    if 'instagram' in player_links[0]:
        player['Insta Handle'] = player_links[0].replace('https://instagram.com/', '')
    else:
        player['Insta Handle'] = 'N/A'
    insta_handle.append(player)

df2 = pd.DataFrame(insta_handle)
df2
# Out:
#                  Name    Insta Handle
# 0         Tyler Herro    nolimitherro
# 1         Bam Adebayo         Bam1of1
# 2      Andrew Wiggins       22wiggins
# 3     Davion Mitchell       daaay____
# 4        Jimmy Butler     jimmybutler
# 5        Terry Rozier             N/A
# 6        Nikola Jović    nikolajovicc
# 7   Haywood Highsmith     haywoodjr24
# 8     Duncan Robinson          d_bo20
# 9         Kel'el Ware      kelelware_
# 10   Jaime Jaquez Jr.       trippplej
# 11          Dru Smith       dru_smith
# 12    Josh Richardson         jrich_0
# 13      Kyle Anderson      teamslowmo
# 14         Alec Burks     alecburks13
# 15      Pelle Larsson   pellelarsson_
# 16      Thomas Bryant       nolimittb
# 17         Kevin Love       kevinlove
# 18     Keshad Johnson    kj_showtime0
# 19   Josh Christopher          jaygup
# 20     Isaiah Stevens  isaiahstevens4

# %%
height_weight_position = []

for row in per_game.find_all('tr')[1:-1]:
    player = {}
    name_td = row.find('td', {'data-stat': 'name_display'})
    a_tag = name_td.find('a')['href']
    player_url = 'https://www.basketball-reference.com' + a_tag
    player_request = requests.get(player_url)
    time.sleep(random.uniform(2,5))
    player_soup = BeautifulSoup(player_request.content, 'lxml')
    player_info = player_soup.find(name = 'div', attrs = {'id' : 'info', 'class' : 'players'})
    player['Name'] = row.find('a').text.strip()
    position_tag = player_info.find('strong', string=lambda text: text and 'Position' in text)
    position = ' '.join(position_tag.next_sibling.text.strip().split()[:-1])
    player['Position'] = position
    p_tag = position_tag.find_parent('p').find_next_sibling()
    spans = p_tag.find_all('span')
    height, weight = spans[0].text, spans[1].text
    player['Height'] = height
    player['Weight (lbs)'] = weight[:-2]
    height_weight_position.append(player)

df3 = pd.DataFrame(height_weight_position)
df3
# Out:
#                  Name                                          Position  \
# 0         Tyler Herro                                    Shooting Guard
# 1         Bam Adebayo                          Center and Power Forward
# 2      Andrew Wiggins                   Small Forward and Power Forward
# 3     Davion Mitchell                                       Point Guard
# 4        Jimmy Butler  Small Forward, Shooting Guard, and Power Forward
# 5        Terry Rozier                    Point Guard and Shooting Guard
# 6        Nikola Jović                                     Power Forward
# 7   Haywood Highsmith                   Small Forward and Power Forward
# 8     Duncan Robinson                  Small Forward and Shooting Guard
# 9         Kel'el Ware                                            Center
# 10   Jaime Jaquez Jr.                                     Small Forward
# 11          Dru Smith                                    Shooting Guard
# 12    Josh Richardson                  Shooting Guard and Small Forward
# 13      Kyle Anderson                   Small Forward and Power Forward
# 14         Alec Burks                  Shooting Guard and Small Forward
# 15      Pelle Larsson                                    Shooting Guard
# 16      Thomas Bryant                                            Center
# 17         Kevin Love                          Power Forward and Center
# 18     Keshad Johnson                                     Small Forward
# 19   Josh Christopher                                    Shooting Guard
# 20     Isaiah Stevens                                       Point Guard
#
#    Height Weight (lbs)
# 0     6-5          195
# 1     6-9          255
# 2     6-7          197
# 3     6-2          205
# 4     6-7          230
# 5     6-1          190
# 6    6-10          209
# 7     6-7          220
# 8     6-7          215
# 9     7-0          230
# 10    6-6          225
# 11    6-3          203
# 12    6-5          200
# 13    6-9          230
# 14    6-6          214
# 15    6-5          215
# 16   6-10          248
# 17    6-8          251
# 18    6-6          225
# 19    6-5          215
# 20    6-0          185

# %%
from functools import reduce

dfs = [df3, df2, df1]

merged_df = reduce(lambda left, right: pd.merge(left, right, on='Name', how='inner'), dfs)
merged_df
# Out:
#                  Name                                          Position  \
# 0         Tyler Herro                                    Shooting Guard
# 1         Bam Adebayo                          Center and Power Forward
# 2      Andrew Wiggins                   Small Forward and Power Forward
# 3     Davion Mitchell                                       Point Guard
# 4        Jimmy Butler  Small Forward, Shooting Guard, and Power Forward
# 5        Terry Rozier                    Point Guard and Shooting Guard
# 6        Nikola Jović                                     Power Forward
# 7   Haywood Highsmith                   Small Forward and Power Forward
# 8     Duncan Robinson                  Small Forward and Shooting Guard
# 9         Kel'el Ware                                            Center
# 10   Jaime Jaquez Jr.                                     Small Forward
# 11          Dru Smith                                    Shooting Guard
# 12    Josh Richardson                  Shooting Guard and Small Forward
# 13      Kyle Anderson                   Small Forward and Power Forward
# 14         Alec Burks                  Shooting Guard and Small Forward
# 15      Pelle Larsson                                    Shooting Guard
# 16      Thomas Bryant                                            Center
# 17         Kevin Love                          Power Forward and Center
# 18     Keshad Johnson                                     Small Forward
# 19   Josh Christopher                                    Shooting Guard
# 20     Isaiah Stevens                                       Point Guard
#
#    Height Weight (lbs)    Insta Handle Age Min PG Field Goal % Rebounds PG  \
# 0     6-5          195    nolimitherro  25   35.4         .472         5.2
# 1     6-9          255         Bam1of1  27   34.3         .485         9.6
# 2     6-7          197       22wiggins  29   32.1         .458         4.2
# 3     6-2          205       daaay____  26   31.6         .504         2.7
# 4     6-7          230     jimmybutler  35   30.6         .540         5.2
# 5     6-1          190             N/A  30   25.9         .391         3.7
# 6    6-10          209    nikolajovicc  21   25.1         .456         3.9
# 7     6-7          220     haywoodjr24  28   24.6         .458         3.4
# 8     6-7          215          d_bo20  30   24.1         .437         2.3
# 9     7-0          230      kelelware_  20   22.2         .554         7.4
# 10    6-6          225       trippplej  23   20.7         .461         4.4
# 11    6-3          203       dru_smith  27   19.1         .508         2.6
# 12    6-5          200         jrich_0  31   18.8         .289         1.5
# 13    6-9          230      teamslowmo  31   18.4         .493         3.8
# 14    6-6          214     alecburks13  33   17.6         .424         2.5
# 15    6-5          215   pellelarsson_  23   14.2         .438         1.7
# 16   6-10          248       nolimittb  27   11.5         .429         3.2
# 17    6-8          251       kevinlove  36   10.9         .357         4.1
# 18    6-6          225    kj_showtime0  23    6.1         .692         1.8
# 19    6-5          215          jaygup  23    4.9         .355         0.6
# 20    6-0          185  isaiahstevens4  24    2.0         .000         0.7
#
#    Assists PG Steals PG Blocks PG Turnovers PG Points PG
# 0         5.5       0.9       0.2          2.6      23.9
# 1         4.3       1.3       0.7          2.1      18.1
# 2         3.3       1.2       1.0          2.5      19.0
# 3         5.3       1.4       0.3          1.7      10.3
# 4         4.8       1.1       0.4          1.2      17.0
# 5         2.6       0.6       0.2          1.2      10.6
# 6         2.8       0.8       0.3          1.3      10.7
# 7         1.5       0.9       0.5          0.7       6.5
# 8         2.4       0.5       0.1          1.2      11.0
# 9         0.9       0.6       1.1          0.9       9.3
# 10        2.5       0.9       0.2          1.5       8.6
# 11        1.6       1.5       0.4          1.2       6.2
# 12        1.5       1.0       0.1          1.0       4.0
# 13        2.6       0.6       0.5          0.7       6.7
# 14        1.1       0.6       0.1          0.6       7.3
# 15        1.2       0.6       0.1          0.4       4.6
# 16        0.4       0.1       0.9          0.2       4.1
# 17        1.0       0.7       0.2          0.6       5.3
# 18        0.3       0.3       0.3          0.3       2.7
# 19        0.6       0.4       0.2          0.4       2.0
# 20        0.0       0.3       0.0          0.0       0.0
